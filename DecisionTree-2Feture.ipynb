# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv("DataSet/00-fruits.csv")
df.head()
# Out:
#    Weight  Colour   Label
# 0     303       3  Banana
# 1     370       1   Apple
# 2     298       3  Banana
# 3     277       3  Banana
# 4     377       4   Apple

# %%
df.isnull().sum()
# Out:
# Weight    0
# Colour    0
# Label     0
# dtype: int64

# %%
plt.scatter(df.Weight, df.Colour)

# %%
sns.scatterplot(data=df,
                x="Weight" ,y= "Colour", hue="Label",
                style="Label",s=100)
# Out:
# <Axes: xlabel='Weight', ylabel='Colour'>

# %% [markdown]
# <h3>Model</h3>

# %%
x = df.drop(["Label"], axis=1)
y = df.Label

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# <h3>Prediction</h3>

# %%
x_input = [[400,1]]

y_predict = model.predict(x_input)
y_predict
# Out:
# C:\Users\Two\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Apple'], dtype=object)

# %%
x_input = [[400,1], [200,3]]

y_predict = model.predict(x_input)
y_predict
# Out:
# C:\Users\Two\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Apple', 'Banana'], dtype=object)

# %% [markdown]
# <h3>Decision Tree</h3>

# %%
from sklearn.tree import plot_tree

data_feature_name = ['size']

plt.subplots(nrows=1 ,ncols=1, figsize=(5,4), dpi=96)
fruit_class = ["Apple","Banana"]
plot_tree(model,
          filled=True, rounded=True,
          feature_names=data_feature_name,
          class_names=fruit_class,)
# Out:
# [Text(0.5, 0.75, 'size <= 335.0\ngini = 0.498\nsamples = 17\nvalue = [8, 9]\nclass = Banana'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Banana'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Apple')]

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# x = np.array(x)
# y = np.array(y)

# plot_decision_regions(x, y, clf=model)
